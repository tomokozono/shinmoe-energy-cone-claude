# %%
import ipywidgets as widgets
from IPython.display import display

test_slider = widgets.FloatSlider(
    value=0.25,
    min=0.2,
    max=0.5,
    step=0.01,
    description="mu",
    continuous_update=False,
    readout_format=".2f",
)
display(test_slider)
# Out:
# FloatSlider(value=0.25, continuous_update=False, description='mu', max=0.5, min=0.2, step=0.01)

# %%
import sys
print(sys.executable)

import ipywidgets
print(ipywidgets.__version__)
# Out:
# /Users/tomo/Documents/Numerical/EnergyCone/.venvec/bin/python
# 8.1.8
